# %% [markdown]
# # Working with date and time

# %% [markdown]
# - ## Note:
# Do not Execute this file. This file is only for readinfd and Understanding purpose.
# No dataset is used in this notebook.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Date

# %% [markdown]
# ### converting the Object(String) date into datetime

# %%
df['column'] = pd.to_datetime(df['column'])

# %% [markdown]
# ### Extract Year

# %%
df['column_year'] = df['column'].dt.year

# %% [markdown]
# ### Extract Month

# %%
df['date_month'] = df['column'].dt.month

# %% [markdown]
# ### Extract Month Name

# %%
df['date_month'] = df['column'].dt.month_name()

# %% [markdown]
# ### Extract Day of month

# %%
df['date_day'] = df['column'].dt.day

# %% [markdown]
# ### Extract days of Week

# %%
df['date_dayofweek'] = df['column'].dt.dayofweek

# %% [markdown]
# ### Extract day of Week name

# %%
df['date_dayofweek_names'] = df['column'].dt.day_name()

# %% [markdown]
# ### Is Weekend?

# %%
df['date_is_weekend'] = np.where(df['date_dayofweek_names'].isin(['Sunday','Saturday']), 1,0)

# %% [markdown]
# ### Extract Week number of year

# %%
df['date_week'] = df['column'].dt.week

# %% [markdown]
# ### Extract time elapsed between dates

# %%
import datetime

today = datetime.today()

datetime.datetime(2025, 4, 16, 2, 16, 701379)

today - df['date']  # finds the time elapsed between current datetime and given datetime

# %%
(today - date['date']).dt.days # Finds how many days elapsed

# %% [markdown]
# ## Time

# %% [markdown]
# ### Extract hour

# %% [markdown]
# df['hour'] = time['date'].dt.hour

# %% [markdown]
# ### Extract Minute

# %%
df['min'] = time['date'].dt.minute

# %% [markdown]
# ### Extract seconds

# %%
df['sec'] = time['date'].dt.second
