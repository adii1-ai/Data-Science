# %% [markdown]
# # Handelling Missing Values in Data

# %% [markdown]
# - If data is missing in the dataframe then there are 2 ways to Handle Them:
#
#             1] Remove row of missing data
#             2] Impute the Values
#                     - Mean Imputation
#                     - Median Imputation
#                     - Mode Imputation
#                     - Random Value
#                     - Forward Fill
#                     - Backward Fill

# %%
import numpy as numpy
import pandas as pandas
import matplotlib.pyplot as plt
